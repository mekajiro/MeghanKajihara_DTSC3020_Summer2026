# %% [markdown]
# <a href="https://colab.research.google.com/github/mekajiro/MeghanKajihara_DTSC3020_Summer2026/blob/main/assignment_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Save work frequently w/ Ctrl+S

# %%
name = "Meghan"
nickname = "Roach"
print(name +" a.k.a "+ nickname)
# Out:
# Meghan a.k.a Roach
